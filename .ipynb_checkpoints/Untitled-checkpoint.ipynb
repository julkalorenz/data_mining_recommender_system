# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ratings_df = pd.read_csv("data/ratings.csv").drop("timestamp", axis=1)

# %%
test_ratings = ratings_df.sample(int(len(ratings_df)*0.2), random_state=0xc00ff3)
sampled_indices = test_ratings.index

test_pairs =  test_ratings[["userId", "movieId"]]
actual_ratings = test_ratings["rating"]

train_ratings = ratings_df.drop(sampled_indices)

del ratings_df

# %%
movies_df = pd.read_csv("data/movies.csv").drop("title", axis=1)
movies_df
# Out:
#       movieId                                       genres
# 0           1  Adventure|Animation|Children|Comedy|Fantasy
# 1           2                   Adventure|Children|Fantasy
# 2           3                               Comedy|Romance
# 3           4                         Comedy|Drama|Romance
# 4           5                                       Comedy
# ...       ...                                          ...
# 9737   193581              Action|Animation|Comedy|Fantasy
# 9738   193583                     Animation|Comedy|Fantasy
# 9739   193585                                        Drama
# 9740   193587                             Action|Animation
# 9741   193609                                       Comedy
#
# [9742 rows x 2 columns]

# %%
plt.show()

# %%
train_ratings_merged = pd.merge(train_ratings, movies_df, on="movieId")
train_ratings_merged
# Out:
#        userId  movieId  rating                                       genres
# 0           1        1     4.0  Adventure|Animation|Children|Comedy|Fantasy
# 1           1        3     4.0                               Comedy|Romance
# 2           1        6     4.0                        Action|Crime|Thriller
# 3           1       50     5.0                       Crime|Mystery|Thriller
# 4           1       70     3.0                Action|Comedy|Horror|Thriller
# ...       ...      ...     ...                                          ...
# 80664     610   164179     5.0                                       Sci-Fi
# 80665     610   166528     4.0              Action|Adventure|Fantasy|Sci-Fi
# 80666     610   168248     5.0                        Action|Crime|Thriller
# 80667     610   168250     5.0                                       Horror
# 80668     610   168252     5.0                                Action|Sci-Fi
#
# [80669 rows x 4 columns]

# %%
train_ratings_merged["genres"] = train_ratings_merged["genres"].str.split("|") 
train_ratings_merged = train_ratings_merged.explode('genres').reset_index(drop=True)
train_ratings_merged
# Out:
#         userId  movieId  rating     genres
# 0            1        1     4.0  Adventure
# 1            1        1     4.0  Animation
# 2            1        1     4.0   Children
# 3            1        1     4.0     Comedy
# 4            1        1     4.0    Fantasy
# ...        ...      ...     ...        ...
# 219788     610   168248     5.0      Crime
# 219789     610   168248     5.0   Thriller
# 219790     610   168250     5.0     Horror
# 219791     610   168252     5.0     Action
# 219792     610   168252     5.0     Sci-Fi
#
# [219793 rows x 4 columns]

# %%
movies_df.groupby("genres").count()
# we will delete no genres because it is not good for similarity comparison
# Out:
#                                      movieId
# genres
# (no genres listed)                        34
# Action                                    60
# Action|Adventure                          32
# Action|Adventure|Animation                18
# Action|Adventure|Animation|Children        6
# ...                                      ...
# Sci-Fi|Thriller                           23
# Sci-Fi|Thriller|IMAX                       1
# Thriller                                  84
# War                                        4
# Western                                   23
#
# [951 rows x 1 columns]

# %%
average_genre_score = train_ratings_merged.drop(["userId", "movieId"], axis=1).groupby("genres").mean()
genre_avg_score_map = average_genre_score['rating'].to_dict()
average_genre_score
# Out:
#                       rating
# genres
# (no genres listed)  3.392857
# Action              3.444614
# Adventure           3.511280
# Animation           3.635266
# Children            3.415320
# Comedy              3.388298
# Crime               3.659421
# Documentary         3.800513
# Drama               3.654682
# Fantasy             3.486832
# Film-Noir           3.930334
# Horror              3.262924
# IMAX                3.621993
# Musical             3.551243
# Mystery             3.625345
# Romance             3.510554
# Sci-Fi              3.456035
# Thriller            3.492580
# War                 3.803266
# Western             3.583066

# %%
# X = train_ratings_merged.pivot_table(index="userId", columns="genres", values="rating", aggfunc="mean").drop("(no genres listed)", axis=1).fillna(69)
X = train_ratings_merged.pivot_table(index="userId", columns="genres", values="rating", aggfunc="mean").drop("(no genres listed)", axis=1).fillna(genre_avg_score_map)
X
# Out:
# genres    Action  Adventure  Animation  Children    Comedy     Crime  \
# userId
# 1       4.333333   4.400000   4.653846  4.552632  4.328571  4.425000
# 2       3.900000   4.166667   3.635266  3.415320  4.000000  3.800000
# 3       3.400000   2.555556   0.500000  0.500000  1.250000  0.500000
# 4       3.136364   3.363636   4.000000  3.750000  3.441558  3.894737
# 5       3.125000   3.250000   4.200000  4.000000  3.538462  3.875000
# ...          ...        ...        ...       ...       ...       ...
# 606     3.170635   3.483607   3.661765  3.375000  3.543544  3.668224
# 607     3.763636   3.657143   3.333333  3.692308  3.268293  3.588235
# 608     3.340000   3.223776   3.122222  2.400000  2.766667  3.622951
# 609     3.111111   3.333333   3.635266  3.415320  3.500000  3.400000
# 610     3.602941   3.696682   3.946809  3.662791  3.739583  3.802691
#
# genres  Documentary     Drama   Fantasy  Film-Noir    Horror      IMAX  \
# userId
# 1          3.800513  4.472727  4.382353   5.000000  3.583333  3.621993
# 2          4.333333  3.933333  3.486832   3.930334  3.000000  3.750000
# 3          3.800513  0.807692  3.375000   3.930334  4.800000  3.621993
# 4          3.000000  3.389474  3.692308   5.000000  4.000000  3.621993
# 5          3.800513  3.777778  4.200000   3.930334  3.000000  3.666667
# ...             ...       ...       ...        ...       ...       ...
# 606        3.750000  3.781961  3.601266   3.857143  3.410256  3.038462
# 607        3.800513  4.120690  3.631579   3.930334  4.068966  5.000000
# 608        3.200000  3.468610  2.938202   3.750000  3.298611  4.150000
# 609        3.800513  3.375000  3.486832   3.930334  3.500000  3.000000
# 610        4.250000  3.880829  3.520661   4.277778  3.510331  3.607692
#
# genres   Musical   Mystery   Romance    Sci-Fi  Thriller       War   Western
# userId
# 1       4.650000  4.062500  4.347826  4.250000  4.152174  4.411765  4.166667
# 2       3.551243  4.000000  4.500000  3.875000  3.833333  3.803266  3.500000
# 3       3.551243  3.625345  0.500000  4.166667  4.000000  0.500000  3.583066
# 4       3.800000  3.368421  3.261905  2.500000  3.466667  3.333333  3.571429
# 5       4.250000  3.625345  3.111111  2.500000  3.666667  3.333333  3.000000
# ...          ...       ...       ...       ...       ...       ...       ...
# 606     3.742857  3.801370  3.728873  3.532787  3.553459  3.745455  3.392857
# 607     3.750000  4.666667  3.739130  3.400000  4.276596  5.000000  4.000000
# 608     2.857143  3.620370  2.906977  3.295620  3.559809  3.593750  2.928571
# 609     3.551243  3.625345  3.250000  3.000000  3.272727  3.500000  4.000000
# 610     3.900000  3.712766  3.780612  3.687817  3.561881  3.728571  3.740000
#
# [610 rows x 19 columns]

# %%
from sklearn.cluster import KMeans

# %%
# %%time
inertias = []
Ks = range(4,20)
for k in Ks:
    kmeans = KMeans(n_clusters=k, init="k-means++", random_state=0xc00ff3).fit(X)
    inertias.append(kmeans.inertia_)

sns.lineplot(x=Ks, y=inertias)
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a594a4860>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a594a44a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a594a4860>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a594a4540>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a597d84a0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# /home/krzys/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/krzys/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# CPU times: user 8.54 s, sys: 5.76 s, total: 14.3 s
# Wall time: 2.07 s
# <Axes: >

# %%
best_k = 3

# %%
# %%time

kmeans = KMeans(n_clusters=best_k, init="k-means++", random_state=0xc00ff3).fit(X)
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a5916e0c0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7e6a5916e0c0>
# Traceback (most recent call last):
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/krzys/miniconda3/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# CPU times: user 406 ms, sys: 332 ms, total: 738 ms
# Wall time: 109 ms

# %%
user_clusters = pd.DataFrame({"userId": X.index, "cluster": kmeans.labels_}).set_index("userId")
user_clusters
# Out:
#         cluster
# userId
# 1             0
# 2             0
# 3             1
# 4             2
# 5             2
# ...         ...
# 606           2
# 607           0
# 608           2
# 609           2
# 610           2
#
# [610 rows x 1 columns]

# %%
sns.countplot(data = user_clusters, x = "cluster")
# Out:
# <Axes: xlabel='cluster', ylabel='count'>

# %%
cluster_ratings = pd.merge(train_ratings, user_clusters, how="left", on="userId").drop("userId", axis=1)
cluster_ratings
# Out:
#        movieId  rating  cluster
# 0            1     4.0        0
# 1            3     4.0        0
# 2            6     4.0        0
# 3           50     5.0        0
# 4           70     3.0        0
# ...        ...     ...      ...
# 80664   164179     5.0        2
# 80665   166528     4.0        2
# 80666   168248     5.0        2
# 80667   168250     5.0        2
# 80668   168252     5.0        2
#
# [80669 rows x 3 columns]

# %%
cluster_ratings = cluster_ratings.groupby(["cluster", "movieId"]).mean()

cluster_ratings
# Out:
#                    rating
# cluster movieId
# 0       1        4.310127
#         2        3.919355
#         3        3.718750
#         5        3.642857
#         6        4.159091
# ...                   ...
# 2       193579   3.500000
#         193581   4.000000
#         193583   3.500000
#         193585   3.500000
#         193609   4.000000
#
# [16789 rows x 1 columns]

# %%
users_not_in_training = 0
movies_not_watched_in_cluster = 0
movie_not_in_training = 0

average_ranking = train_ratings["rating"].mean()
def predict(user_id, movie_id):
    global users_not_in_training, movies_not_watched_in_cluster, movie_not_in_training

    if user_id not in user_clusters.index:
        users_not_in_training += 1
        return average_ranking
    
    cluster = int(user_clusters.loc[user_id, "cluster"])
    
    try:
        rating = cluster_ratings.loc[(cluster, movie_id), "rating"]
        
    except KeyError:
        rating = train_ratings.loc[train_ratings["movieId"] == movie_id]["rating"].mean()
        if np.isnan(rating):
            movie_not_in_training += 1
            return average_ranking
        else:
            movies_not_watched_in_cluster += 1
            return rating

        
    return rating

# %%
# %%time
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_predicted = test_pairs.apply(lambda row: predict(row['userId'], row['movieId']), axis=1)

total = len(y_predicted)
print(users_not_in_training/total)
print(movies_not_watched_in_cluster/total)
print(movie_not_in_training/total)

print("//////////////")
print(mean_absolute_error(y_predicted, actual_ratings))
print(mean_squared_error(y_predicted, actual_ratings))
# Out:
# 0.0
# 0.2957306490801805
# 0.23979768929439182
# //////////////
# 0.7342763898787629
# 0.9181526321101091
# CPU times: user 2.2 s, sys: 0 ns, total: 2.2 s
# Wall time: 2.21 s

# %%
just_fucking_averages = train_ratings.drop("userId", axis=1).groupby("movieId").mean()
just_fucking_averages
# Out:
#            rating
# movieId
# 1        3.924157
# 2        3.424731
# 3        3.255556
# 4        2.100000
# 5        3.025641
# ...           ...
# 193579   3.500000
# 193581   4.000000
# 193583   3.500000
# 193585   3.500000
# 193609   4.000000
#
# [9000 rows x 1 columns]

# %%
c = 0
def just_average_predict(user_id, movie_id):
    global c
    try:
        rating = just_fucking_averages.at[movie_id, "rating"]
    except KeyError:
        rating = average_ranking
        c += 1
    return rating

# %%
# just_fucking_averages = pd.read_csv("data/ratings.csv").drop(["timestamp", "userId"], axis=1).groupby("movieId").mean()

y_predicted = test_pairs.apply(lambda row: just_average_predict(row['userId'], row['movieId']), axis=1)
print(mean_absolute_error(y_predicted, actual_ratings))
mean_squared_error(y_predicted, actual_ratings)
# Out:
# 0.7503034282382882
# 0.9404938436807428
